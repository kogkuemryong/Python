# %%
import pandas as pd
import lxml

# %%
url ='http://211.43.210.44/tvguide/index.php?main=cable&sub=cable15'

# %%
table = pd.read_html(url)

# %%
table[18]
# Out:
#          0        1        2
# 0  08.17 월  08.18 화  08.19 수

# %%
table[19]
# Out:
#     0      1      2      3        4  5
# 0  시간  롯데홈쇼핑  현대홈쇼핑  CJ오쇼핑  GS SHOP  ▶

# %%
table[20]
# Out:
#       0                                  1                          2  \
# 0   00시                                NaN                        NaN
# 1   01시                                NaN     00 [무료체험] 벨라몬스터 스킨핏마스크
# 2   02시                  00 심야재방송 15 심야재방송               00 다시보는 인기상품
# 3   03시  05 생활안전행동요령프로그램 35 심야재방송 55 심야재방송                        NaN
# 4   04시                           35 심야재방송                        NaN
# 5   05시                  25 심야재방송 55 심야재방송                        NaN
# 6   06시                            15 건강식품            00 팔레오 포스트바이오틱스
# 7   07시                             15 캐릭터                    15 에이앤디
# 8   08시                                NaN       15 [최신상] 더마픽스 콜라겐마스크
# 9   09시                            25 건강식품         25 [무료체험] 수려한 효윤기초
# 10  10시                            25 건강식품         25 [방송최저가] 캐치온 마스크
# 11  11시                           35 색조화장품                  40 클럽노블레스
# ...
