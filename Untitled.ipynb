# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data =pd.read_csv('ns_weather.csv')

# %%
data['revenue'].plot()

# %%
# 2017/1/1 까지의 데이터를 트레이닝셋.
# 그 이후 데이터를 테스트셋으로 한다.
split_date = pd.Timestamp('2019-06-30')

# %%
train = data.loc[:split_date, ['tra']]
test = data.loc[split_date:, ['trade_price_idx_value']]

ax = train.plot()
test.plot(ax=ax)
plt.legend(['train', 'test'])
vi
